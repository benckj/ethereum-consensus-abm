# %%
df = pd.read_csv('tests-for-reports/result_in_csv/pb_consideration_reports_average.csv')
df = df.iloc[:, 2: ]

list(df['proposer_vote_boost'].values)
# Out:
# [0.37,
#  0.38,
#  0.39,
#  0.4,
#  0.41,
#  0.42,
#  0.43,
#  0.44,
#  0.45,
#  0.37,
#  0.38,
#  0.39,
#  0.4,
#  0.41,
#  0.42,
#  0.43,
#  0.44,
#  0.45,
#  0.37,
#  0.38,
#  0.39,
#  0.4,
#  0.41,
#  0.42,
#  0.43,
#  0.44,
#  0.45,
#  0.37,
#  0.38,
#  0.39,
#  0.4,
#  0.41,
#  0.42,
#  0.43,
#  0.44,
#  0.45,
#  0.37,
#  0.38,
#  0.39,
#  0.4,
#  0.41,
#  0.42,
#  0.43,
#  0.44,
#  0.45,
#  0.37,
#  0.38,
#  0.39,
#  0.4,
#  0.41,
#  0.42,
#  0.43,
#  0.44,
#  0.45,
#  0.37,
#  0.38,
#  0.39,
#  0.4,
#  0.41,
#  0.42,
#  0.43,
#  0.44,
#  0.45,
#  0.37,
#  0.38,
#  0.39,
#  0.4,
#  0.41,
#  0.42,
#  0.43,
#  0.44,
#  0.45,
#  0.37,
#  0.38,
#  0.39,
#  0.4,
#  0.41,
#  0.42,
#  0.43,
#  0.44,
#  0.45,
#  0.37,
#  0.38,
#  0.39,
#  0.4,
#  0.41,
#  0.42,
#  0.43,
#  0.44,
#  0.45,
#  0.37,
#  0.38,
#  0.39,
#  0.4,
#  0.41,
#  0.42,
#  0.43,
#  0.44,
#  0.45,
#  0.37,
#  0.38,
#  0.39,
#  0.4,
#  0.41,
#  0.42,
#  0.43,
#  0.44,
#  0.45,
#  0.37,
#  0.38,
#  0.39,
#  0.4,
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

df = pd.read_csv('tests-for-reports/result_in_csv/pb_consideration_reports_average.csv')
df = df.iloc[:, 2: ]

fig, ax = plt.subplots(figsize=(5,5))

# Define the color values and their corresponding ranges
cmap = plt.colormaps["viridis"]
# norm = mpl.colors.LogNorm(
#             vmin=0.1,
#             vmax=900
#             )
norm = plt.Normalize(vmin=0.37, vmax=0.46)

df['success_in_attempts'] = df['successful_reorgs']/df['attackable_slots_count']
df.fillna(0)
df2 = df.loc[:,["malicious_stake", "proposer_vote_boost", "success_in_attempts"]].groupby(["malicious_stake", "proposer_vote_boost"]).mean().reset_index(level=-1).reset_index(level=-1).reset_index(level=-1)

# df2 = df2[df2.loc[:,"malicious_stake"] == 0.15]
# df2 = df2[df2.loc[:,"tau_attestation"] != 656.1]
# df2 = df2[df2.loc[:,"tau_attestation"] != 218.7]
# df2 = df2[df2.loc[:,"tau_block"] > 1.37][df2.loc[:,"tau_block"] < 1.39]
# df2 = df2[df2.loc[:,"tau_block"] != 24.3]
df2

ax.set_title('malicious_stake vs success_in_attempts')
ax.set_xlabel('malicious_stake')
ax.set_ylabel('success_in_attempts') 
# ax.set_xscale('log')
for i in df2.index:
    ax.plot(df2.loc[i, 'malicious_stake'],  df2.loc[i, 'success_in_attempts'], 'x', color=cmap(norm(df2.loc[i, "proposer_vote_boost"])))

plt.colorbar(plt.cm.ScalarMappable(norm=norm,cmap=cmap),
                ax=ax, label="proposer_vote_boost")

# fig.savefig('analysis-malicious_stake2successful_reorgs.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

df = pd.read_csv('malicious-modeling_final_2.csv')
df = df.iloc[:, 2: ]

fig, ax = plt.subplots(figsize=(5,5))

# Define the color values and their corresponding ranges
cmap = plt.colormaps["viridis"]
# norm = mpl.colors.LogNorm(
#             vmin=0.1,
#             vmax=900
#             )
norm = plt.Normalize(vmin=5, vmax=11)

df['success_in_attempts'] = df['successful_reorgs']/df['attackable_slots_count']
df.fillna(0)
df2 = df.loc[:,["success_in_attempts", "adversary_offset", "tau_block"]].groupby(["tau_block", "adversary_offset"]).mean().reset_index(level=-1).reset_index(level=-1).reset_index(level=-1)

# df2 = df2[df2.loc[:,"malicious_stake"] == 0.15]
# df2 = df2[df2.loc[:,"tau_attestation"] != 656.1]
# df2 = df2[df2.loc[:,"tau_attestation"] != 218.7]
# df2 = df2[df2.loc[:,"tau_block"] > 1.37][df2.loc[:,"tau_block"] < 1.39]
# df2 = df2[df2.loc[:,"tau_block"] != 24.3]
df2

ax.set_title('tau_block vs success_in_attempts')
ax.set_xlabel('tau_block')
ax.set_ylabel('success_in_attempts') 
# ax.set_xscale('log')
for i in df2.index:
    ax.plot(df2.loc[i, 'tau_block'],  df2.loc[i, 'success_in_attempts'], 'x', color=cmap(norm(df2.loc[i, "adversary_offset"])))

plt.colorbar(plt.cm.ScalarMappable(norm=norm,cmap=cmap),
                ax=ax, label="adversary_offset")

# fig.savefig('mmanalysis-malicious_stake2successful_reorgs_3.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

df = pd.read_csv('malicious-modeling_final_3.csv')
df = df.iloc[:, 2: ]

fig, ax = plt.subplots(figsize=(5,5))

# Define the color values and their corresponding ranges
cmap = plt.colormaps["viridis"]
# norm = mpl.colors.LogNorm(
#             vmin=0.1,
#             vmax=900
#             )
norm = plt.Normalize(vmin=5, vmax=11)

df['success_in_attempts'] = df['successful_reorgs']/df['attackable_slots_count']
df.fillna(0)
df2 = df.loc[:,["success_in_attempts", "adversary_offset", "tau_block"]].groupby(["tau_block", "adversary_offset"]).mean().reset_index(level=-1).reset_index(level=-1).reset_index(level=-1)

# df2 = df2[df2.loc[:,"malicious_stake"] == 0.15]
# df2 = df2[df2.loc[:,"tau_attestation"] != 656.1]
# df2 = df2[df2.loc[:,"tau_attestation"] != 218.7]
# df2 = df2[df2.loc[:,"tau_block"] > 1.37][df2.loc[:,"tau_block"] < 1.39]
# df2 = df2[df2.loc[:,"tau_block"] != 24.3]
df2

ax.set_title('tau_block vs success_in_attempts')
ax.set_xlabel('tau_block')
ax.set_ylabel('success_in_attempts') 
# ax.set_xscale('log')
for i in df2.index:
    ax.plot(df2.loc[i, 'tau_block'],  df2.loc[i, 'success_in_attempts'], 'x', color=cmap(norm(df2.loc[i, "adversary_offset"])))

plt.colorbar(plt.cm.ScalarMappable(norm=norm,cmap=cmap),
                ax=ax, label="adversary_offset")

fig.savefig('mmanalysis-malicious_stake2protected_reorgs_3.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

df = pd.read_csv('malicious-modeling_final_6.csv')
df = df.iloc[:, 2: ]

fig, ax = plt.subplots(figsize=(5,5))

# Define the color values and their corresponding ranges
cmap = plt.colormaps["viridis"]
# norm = mpl.colors.LogNorm(
#             vmin=0.1,
#             vmax=900
#             )
norm = plt.Normalize(vmin=0, vmax=0.5)

df['success_in_attempts'] = df['protected_reorgs']/df['attackable_slots_count']
df.fillna(0)
df2 = df.loc[:,["mainchain_rate", "malicious_stake", "tau_block"]].groupby(["tau_block", "malicious_stake"]).mean().reset_index(level=-1).reset_index(level=-1).reset_index(level=-1)

# df2 = df2[df2.loc[:,"malicious_stake"] == 0.15]
# df2 = df2[df2.loc[:,"tau_attestation"] != 656.1]
# df2 = df2[df2.loc[:,"tau_attestation"] != 218.7]
# df2 = df2[df2.loc[:,"tau_block"] > 1.37][df2.loc[:,"tau_block"] < 1.39]
# df2 = df2[df2.loc[:,"tau_block"] != 24.3]
df2 = df2[df2.loc[:,"tau_block"]%2 == 0]
df2 = df2[df2.loc[:,"tau_block"] < 10]
df2

ax.set_title('tau_block vs mainchain_rate')
ax.set_xlabel('tau_block')
ax.set_ylabel('mainchain_rate') 
# ax.set_xscale('log')
for i in df2.index:
    ax.plot(df2.loc[i, 'tau_block'],  df2.loc[i, 'mainchain_rate'], 'x', color=cmap(norm(df2.loc[i, "malicious_stake"])))

plt.colorbar(plt.cm.ScalarMappable(norm=norm,cmap=cmap),
                ax=ax, label="malicious_stake")
fig.savefig('sidebyside1.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

df = pd.read_csv('malicious-modeling_final_7.csv')
df = df.iloc[:, 2: ]

fig, ax = plt.subplots(figsize=(5,5))

# Define the color values and their corresponding ranges
cmap = plt.colormaps["viridis"]
# norm = mpl.colors.LogNorm(
#             vmin=0.1,
#             vmax=900
#             )
norm = plt.Normalize(vmin=0, vmax=0.5)

df['success_in_attempts'] = df['protected_reorgs']/df['attackable_slots_count']
df.fillna(0)
df2 = df.loc[:,["mainchain_rate", "malicious_stake", "tau_block"]].groupby(["tau_block", "malicious_stake"]).mean().reset_index(level=-1).reset_index(level=-1).reset_index(level=-1)

# df2 = df2[df2.loc[:,"malicious_stake"] == 0.15]
# df2 = df2[df2.loc[:,"tau_attestation"] != 656.1]
# df2 = df2[df2.loc[:,"tau_attestation"] != 218.7]
# df2 = df2[df2.loc[:,"tau_block"] > 1.37][df2.loc[:,"tau_block"] < 1.39]
# df2 = df2[df2.loc[:,"tau_block"] != 24.3]
df2 = df2[df2.loc[:,"tau_block"]%2 == 0]
df2 = df2[df2.loc[:,"tau_block"] < 10]
df2

ax.set_title('tau_block vs mainchain_rate')
ax.set_xlabel('tau_block')
ax.set_ylabel('mainchain_rate') 
# ax.set_xscale('log')
for i in df2.index:
    ax.plot(df2.loc[i, 'tau_block'],  df2.loc[i, 'mainchain_rate'], 'x', color=cmap(norm(df2.loc[i, "malicious_stake"])))

plt.colorbar(plt.cm.ScalarMappable(norm=norm,cmap=cmap),
                ax=ax, label="malicious_stake")
fig.savefig('sidebyside2.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

df = pd.read_csv('malicious-modeling_final_4.csv')
df = df.iloc[:, 2: ]

fig, ax = plt.subplots(figsize=(5,5))

# Define the color values and their corresponding ranges
cmap = plt.colormaps["viridis"]
# norm = mpl.colors.LogNorm(
#             vmin=0.1,
#             vmax=900
#             )
norm = plt.Normalize(vmin=0, vmax=0.5)

df['success_in_attempts'] = df['successful_reorgs']/df['attackable_slots_count']
df.fillna(0)
df2 = df.loc[:,["successful_reorgs", "adversdary", "tau_block"]].groupby(["tau_block", "malicious_stake"]).mean().reset_index(level=-1).reset_index(level=-1).reset_index(level=-1)

# df2 = df2[df2.loc[:,"malicious_stake"] == 0.15]
# df2 = df2[df2.loc[:,"tau_attestation"] != 656.1]
# df2 = df2[df2.loc[:,"tau_attestation"] != 218.7]
# df2 = df2[df2.loc[:,"tau_block"] > 1.37][df2.loc[:,"tau_block"] < 1.39]
# df2 = df2[df2.loc[:,"tau_block"] != 24.3]
# df2 = df2[df2.loc[:,"tau_block"] < 10]
df2

ax.set_title('tau_block vs failed_reorgs')
ax.set_xlabel('tau_block')
ax.set_ylabel('failed_reorgs') 
# ax.set_xscale('log')
for i in df2.index:
    ax.plot(df2.loc[i, 'tau_block'],  df2.loc[i, 'failed_reorgs'], 'x', color=cmap(norm(df2.loc[i, "malicious_stake"])))

plt.colorbar(plt.cm.ScalarMappable(norm=norm,cmap=cmap),
                ax=ax, label="malicious_stake")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

df = pd.read_csv('malicious-modeling_final_6.csv')
df = df.iloc[:, 2: ]

fig, ax = plt.subplots(figsize=(5,5))

# Define the color values and their corresponding ranges
cmap = plt.colormaps["viridis"]
# norm = mpl.colors.LogNorm(
#             vmin=0.1,
#             vmax=900
#             )
norm = plt.Normalize(vmin=0, vmax=0.5)

df['failed_in_attempts'] = df['failed_reorgs']/df['attackable_slots_count']
df.fillna(0)
df2 = df.loc[:,["successful_reorgs", "malicious_stake", "tau_block"]].groupby(["tau_block", "malicious_stake"]).mean().reset_index(level=-1).reset_index(level=-1).reset_index(level=-1)

# df2 = df2[df2.loc[:,"malicious_stake"] == 0.15]
# df2 = df2[df2.loc[:,"tau_attestation"] != 656.1]
# df2 = df2[df2.loc[:,"tau_attestation"] != 218.7]
# df2 = df2[df2.loc[:,"tau_block"] > 1.37][df2.loc[:,"tau_block"] < 1.39]
# df2 = df2[df2.loc[:,"tau_block"] != 24.3]
# df2 = df2[df2.loc[:,"tau_block"] % 2 == 0]
df2

ax.set_title('tau_block vs successful_reorgs')
ax.set_xlabel('tau_block')
ax.set_ylabel('protected_reorgs') 
# ax.set_xscale('log')
for i in df2.index:
    ax.plot(df2.loc[i, 'tau_block'],  df2.loc[i, 'protected_reorgs'], 'x', color=cmap(norm(df2.loc[i, "malicious_stake"])))

plt.colorbar(plt.cm.ScalarMappable(norm=norm,cmap=cmap),
                ax=ax, label="malicious_stake")

fig.savefig('tau_block__protected_reorgs_wo_pb.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

df = pd.read_csv('malicious-modeling_final_7.csv')
df = df.iloc[:, 2: ]

fig, ax = plt.subplots(figsize=(5,5))

# Define the color values and their corresponding ranges
cmap = plt.colormaps["viridis"]
# norm = mpl.colors.LogNorm(
#             vmin=0.1,
#             vmax=900
#             )
norm = plt.Normalize(vmin=0, vmax=0.5)

df['failed_in_attempts'] = df['successful_reorgs']/df['attackable_slots_count']
df.fillna(0)
df2 = df.loc[:,["successful_reorgs", "malicious_stake", "tau_block"]].groupby(["tau_block", "malicious_stake"]).mean().reset_index(level=-1).reset_index(level=-1).reset_index(level=-1)

# df2 = df2[df2.loc[:,"malicious_stake"] == 0.15]
# df2 = df2[df2.loc[:,"tau_attestation"] != 656.1]
# df2 = df2[df2.loc[:,"tau_attestation"] != 218.7]
# df2 = df2[df2.loc[:,"tau_block"] > 1.37][df2.loc[:,"tau_block"] < 1.39]
# df2 = df2[df2.loc[:,"tau_block"] != 24.3]
df2 = df2[df2.loc[:,"tau_block"] % 2 == 0]

ax.set_title('tau_block vs successful_reorgs')
ax.set_xlabel('tau_block')
ax.set_ylabel('successful_reorgs') 
# ax.set_xscale('log')
for i in df2.index:
    ax.plot(df2.loc[i, 'tau_block'],  df2.loc[i, 'successful_reorgs'], 'x', color=cmap(norm(df2.loc[i, "malicious_stake"])))

plt.colorbar(plt.cm.ScalarMappable(norm=norm,cmap=cmap),
                ax=ax, label="malicious_stake")

fig.savefig('tau_block__successful_reorgs_w_pb.png')

# %% [markdown]
# # New Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

df = pd.read_csv('tests-for-reports/result_in_csv/tB&AO_w_HBMS_ideal.csv')
df = df.iloc[:, 2:]

fig, ax = plt.subplots(figsize=(5, 5))

# Define the color values and their corresponding ranges
cmap = plt.colormaps["viridis"]
# norm = mpl.colors.LogNorm(
#             vmin=0.1,
#             vmax=900
#             )
norm = plt.Normalize(vmin=0, vmax=0.7)

df['successful_prevention'] = df['protected_reorgs']/df['attackable_slots_count']
# df.fillna(0)
df2 = df.loc[:, ["successful_prevention", "adversary_offset", "proposer_vote_boost"]].groupby(
    ["proposer_vote_boost", "adversary_offset"]).mean().reset_index(level=-1).reset_index(level=-1).reset_index(level=-1)

# df2 = df2[df2.loc[:,"malicious_stake"] == 0.15]
# df2 = df2[df2.loc[:,"tau_attestation"] != 656.1]
# df2 = df2[df2.loc[:,"tau_attestation"] != 218.7]
# df2 = df2[df2.loc[:,"tau_block"] > 1.37][df2.loc[:,"tau_block"] < 1.39]
# df2 = df2[df2.loc[:,"tau_block"] != 24.3]
# df2 = df2[df2.loc[:,"tau_block"] % 2 == 0]

ax.set_title('adversary_offset vs successful_prevention in Ideal')
ax.set_xlabel('adversary_offset')
ax.set_ylabel('successful_prevention')
# ax.set_xscale('log')
for i in df2.index:
    ax.plot(df2.loc[i, 'adversary_offset'],  df2.loc[i, 'successful_prevention'],
            'x', color=cmap(norm(df2.loc[i, "proposer_vote_boost"])))

plt.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap),
             ax=ax, label="proposer_vote_boost")

# fig.savefig('tau_block__successful_reorgs_w_pb.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

df = pd.read_csv('tests-for-reports/result_in_csv/tB&AO_w_HBMS_worst.csv')
df = df.iloc[:, 2:]

fig, ax = plt.subplots(figsize=(5, 5))

# Define the color values and their corresponding ranges
cmap = plt.colormaps["viridis"]
# norm = mpl.colors.LogNorm(
#             vmin=0.1,
#             vmax=900
#             )
norm = plt.Normalize(vmin=0, vmax=0.7)

df['successful_prevention'] = df['protected_reorgs']/df['attackable_slots_count']
# df.fillna(0)
df2 = df.loc[:, ["successful_prevention", "adversary_offset", "proposer_vote_boost"]].groupby(
    ["proposer_vote_boost", "adversary_offset"]).mean().reset_index(level=-1).reset_index(level=-1).reset_index(level=-1)

# df2 = df2[df2.loc[:,"malicious_stake"] == 0.15]
# df2 = df2[df2.loc[:,"tau_attestation"] != 656.1]
# df2 = df2[df2.loc[:,"tau_attestation"] != 218.7]
# df2 = df2[df2.loc[:,"tau_block"] > 1.37][df2.loc[:,"tau_block"] < 1.39]
# df2 = df2[df2.loc[:,"tau_block"] != 24.3]
# df2 = df2[df2.loc[:,"tau_block"] % 2 == 0]

ax.set_title('adversary_offset vs successful_prevention in Ideal')
ax.set_xlabel('adversary_offset')
ax.set_ylabel('successful_prevention')
# ax.set_xscale('log')
for i in df2.index:
    ax.plot(df2.loc[i, 'adversary_offset'],  df2.loc[i, 'successful_prevention'],
            'x', color=cmap(norm(df2.loc[i, "proposer_vote_boost"])))

plt.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap),
             ax=ax, label="proposer_vote_boost")

# fig.savefig('tau_block__successful_reorgs_w_pb.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

df = pd.read_csv('tests-for-reports/result_in_csv/tB&AO_w_LBMS_ideal.csv')
df = df.iloc[:, 2:]

fig, ax = plt.subplots(figsize=(5, 5))

# Define the color values and their corresponding ranges
cmap = plt.colormaps["viridis"]
# norm = mpl.colors.LogNorm(
#             vmin=0.1,
#             vmax=900
#             )
norm = plt.Normalize(vmin=0, vmax=0.7)

# df['failed_in_attempts'] = df['successful_reorgs']/df['attackable_slots_count']
# df.fillna(0)
df2 = df.loc[:, ["protected_reorgs", "adversary_offset", "proposer_vote_boost"]].groupby(
    ["proposer_vote_boost", "adversary_offset"]).mean().reset_index(level=-1).reset_index(level=-1).reset_index(level=-1)

# df2 = df2[df2.loc[:,"malicious_stake"] == 0.15]
# df2 = df2[df2.loc[:,"tau_attestation"] != 656.1]
# df2 = df2[df2.loc[:,"tau_attestation"] != 218.7]
# df2 = df2[df2.loc[:,"tau_block"] > 1.37][df2.loc[:,"tau_block"] < 1.39]
# df2 = df2[df2.loc[:,"tau_block"] != 24.3]
# df2 = df2[df2.loc[:,"tau_block"] % 2 == 0]

ax.set_title('adversary_offset vs protected_reorgs in Ideal')
ax.set_xlabel('adversary_offset')
ax.set_ylabel('protected_reorgs')
# ax.set_xscale('log')
for i in df2.index:
    ax.plot(df2.loc[i, 'adversary_offset'],  df2.loc[i, 'protected_reorgs'],
            'x', color=cmap(norm(df2.loc[i, "proposer_vote_boost"])))

plt.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap),
             ax=ax, label="proposer_vote_boost")

# fig.savefig('tau_block__successful_reorgs_w_pb.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

df = pd.read_csv('tests-for-reports/result_in_csv/tB&AO_w_LBMS_worst.csv')
df = df.iloc[:, 2:]

fig, ax = plt.subplots(figsize=(5, 5))

# Define the color values and their corresponding ranges
cmap = plt.colormaps["viridis"]
# norm = mpl.colors.LogNorm(
#             vmin=0.1,
#             vmax=900
#             )
norm = plt.Normalize(vmin=0, vmax=0.7)

# df['failed_in_attempts'] = df['successful_reorgs']/df['attackable_slots_count']
# df.fillna(0)
df2 = df.loc[:, ["protected_reorgs", "adversary_offset", "proposer_vote_boost"]].groupby(
    ["proposer_vote_boost", "adversary_offset"]).mean().reset_index(level=-1).reset_index(level=-1).reset_index(level=-1)

# df2 = df2[df2.loc[:,"malicious_stake"] == 0.15]
# df2 = df2[df2.loc[:,"tau_attestation"] != 656.1]
# df2 = df2[df2.loc[:,"tau_attestation"] != 218.7]
# df2 = df2[df2.loc[:,"tau_block"] > 1.37][df2.loc[:,"tau_block"] < 1.39]
# df2 = df2[df2.loc[:,"tau_block"] != 24.3]
# df2 = df2[df2.loc[:,"tau_block"] % 2 == 0]

ax.set_title('adversary_offset vs protected_reorgs in Ideal')
ax.set_xlabel('adversary_offset')
ax.set_ylabel('protected_reorgs')
# ax.set_xscale('log')
for i in df2.index:
    ax.plot(df2.loc[i, 'adversary_offset'],  df2.loc[i, 'protected_reorgs'],
            'x', color=cmap(norm(df2.loc[i, "proposer_vote_boost"])))

plt.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap),
             ax=ax, label="proposer_vote_boost")

# fig.savefig('tau_block__successful_reorgs_w_pb.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

df = pd.read_csv('tests-for-reports/result_in_csv/tB&MS_w_HBAO_ideal.csv')
df = df.iloc[:, 2:]

fig, ax = plt.subplots(figsize=(5, 5))

# Define the color values and their corresponding ranges
cmap = plt.colormaps["viridis"]
# norm = mpl.colors.LogNorm(
#             vmin=0.1,
#             vmax=900
#             )
norm = plt.Normalize(vmin=0, vmax=0.7)

df['successful_percentage'] = df['successful_reorgs']/df['attackable_slots_count']
# df.fillna(0)
df2 = df.loc[:, ["successful_percentage", "malicious_stake", "proposer_vote_boost"]].groupby(
    ["proposer_vote_boost", "malicious_stake"]).mean().reset_index(level=-1).reset_index(level=-1).reset_index(level=-1)

# df2 = df2[df2.loc[:,"malicious_stake"] == 0.15]
# df2 = df2[df2.loc[:,"tau_attestation"] != 656.1]
# df2 = df2[df2.loc[:,"tau_attestation"] != 218.7]
# df2 = df2[df2.loc[:,"tau_block"] > 1.37][df2.loc[:,"tau_block"] < 1.39]
# df2 = df2[df2.loc[:,"tau_block"] != 24.3]
# df2 = df2[df2.loc[:,"tau_block"] % 2 == 0]

ax.set_title('malicious_stake vs successful_percentage in Ideal')
ax.set_xlabel('malicious_stake')
ax.set_ylabel('successful_percentage')
# ax.set_xscale('log')
for i in df2.index:
    ax.plot(df2.loc[i, 'malicious_stake'],  df2.loc[i, 'successful_percentage'],
            'x', color=cmap(norm(df2.loc[i, "proposer_vote_boost"])))

plt.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap),
             ax=ax, label="proposer_vote_boost")

# fig.savefig('tau_block__successful_reorgs_w_pb.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

df = pd.read_csv('tests-for-reports/result_in_csv/tB&MS_w_HBAO_worst.csv')
df = df.iloc[:, 2:]

fig, ax = plt.subplots(figsize=(5, 5))

# Define the color values and their corresponding ranges
cmap = plt.colormaps["viridis"]
# norm = mpl.colors.LogNorm(
#             vmin=0.1,
#             vmax=900
#             )
norm = plt.Normalize(vmin=0, vmax=0.7)

# df['failed_in_attempts'] = df['successful_reorgs']/df['attackable_slots_count']
# df.fillna(0)
df2 = df.loc[:, ["protected_reorgs", "malicious_stake", "proposer_vote_boost"]].groupby(
    ["proposer_vote_boost", "malicious_stake"]).mean().reset_index(level=-1).reset_index(level=-1).reset_index(level=-1)

# df2 = df2[df2.loc[:,"malicious_stake"] == 0.15]
# df2 = df2[df2.loc[:,"tau_attestation"] != 656.1]
# df2 = df2[df2.loc[:,"tau_attestation"] != 218.7]
# df2 = df2[df2.loc[:,"tau_block"] > 1.37][df2.loc[:,"tau_block"] < 1.39]
# df2 = df2[df2.loc[:,"tau_block"] != 24.3]
# df2 = df2[df2.loc[:,"tau_block"] % 2 == 0]

ax.set_title('malicious_stake vs protected_reorgs in Ideal')
ax.set_xlabel('malicious_stake')
ax.set_ylabel('protected_reorgs')
# ax.set_xscale('log')
for i in df2.index:
    ax.plot(df2.loc[i, 'malicious_stake'],  df2.loc[i, 'protected_reorgs'],
            'x', color=cmap(norm(df2.loc[i, "proposer_vote_boost"])))

plt.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap),
             ax=ax, label="proposer_vote_boost")

# fig.savefig('tau_block__successful_reorgs_w_pb.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

df = pd.read_csv('tests-for-reports/result_in_csv/tB&MS_w_LBAO_ideal.csv')
df = df.iloc[:, 2:]

fig, ax = plt.subplots(figsize=(5, 5))

# Define the color values and their corresponding ranges
cmap = plt.colormaps["viridis"]
# norm = mpl.colors.LogNorm(
#             vmin=0.1,
#             vmax=900
#             )
norm = plt.Normalize(vmin=0, vmax=0.7)

# df['failed_in_attempts'] = df['successful_reorgs']/df['attackable_slots_count']
# df.fillna(0)
df2 = df.loc[:, ["protected_reorgs", "malicious_stake", "proposer_vote_boost"]].groupby(
    ["proposer_vote_boost", "malicious_stake"]).mean().reset_index(level=-1).reset_index(level=-1).reset_index(level=-1)

# df2 = df2[df2.loc[:,"malicious_stake"] == 0.15]
# df2 = df2[df2.loc[:,"tau_attestation"] != 656.1]
# df2 = df2[df2.loc[:,"tau_attestation"] != 218.7]
# df2 = df2[df2.loc[:,"tau_block"] > 1.37][df2.loc[:,"tau_block"] < 1.39]
# df2 = df2[df2.loc[:,"tau_block"] != 24.3]
# df2 = df2[df2.loc[:,"tau_block"] % 2 == 0]

ax.set_title('malicious_stake vs protected_reorgs in Ideal')
ax.set_xlabel('malicious_stake')
ax.set_ylabel('protected_reorgs')
# ax.set_xscale('log')
for i in df2.index:
    ax.plot(df2.loc[i, 'malicious_stake'],  df2.loc[i, 'protected_reorgs'],
            'x', color=cmap(norm(df2.loc[i, "proposer_vote_boost"])))

plt.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap),
             ax=ax, label="proposer_vote_boost")

# fig.savefig('tau_block__successful_reorgs_w_pb.png')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

df = pd.read_csv('tests-for-reports/result_in_csv/tB&MS_w_LBAO_worst.csv')
df = df.iloc[:, 2:]

fig, ax = plt.subplots(figsize=(5, 5))

# Define the color values and their corresponding ranges
cmap = plt.colormaps["viridis"]
# norm = mpl.colors.LogNorm(
#             vmin=0.1,
#             vmax=900
#             )
norm = plt.Normalize(vmin=0, vmax=0.7)

# df['failed_in_attempts'] = df['successful_reorgs']/df['attackable_slots_count']
# df.fillna(0)
df2 = df.loc[:, ["protected_reorgs", "malicious_stake", "proposer_vote_boost"]].groupby(
    ["proposer_vote_boost", "malicious_stake"]).mean().reset_index(level=-1).reset_index(level=-1).reset_index(level=-1)

# df2 = df2[df2.loc[:,"malicious_stake"] == 0.15]
# df2 = df2[df2.loc[:,"tau_attestation"] != 656.1]
# df2 = df2[df2.loc[:,"tau_attestation"] != 218.7]
# df2 = df2[df2.loc[:,"tau_block"] > 1.37][df2.loc[:,"tau_block"] < 1.39]
# df2 = df2[df2.loc[:,"tau_block"] != 24.3]
# df2 = df2[df2.loc[:,"tau_block"] % 2 == 0]

ax.set_title('malicious_stake vs protected_reorgs in Ideal')
ax.set_xlabel('malicious_stake')
ax.set_ylabel('protected_reorgs')
# ax.set_xscale('log')
for i in df2.index:
    ax.plot(df2.loc[i, 'malicious_stake'],  df2.loc[i, 'protected_reorgs'],
            'x', color=cmap(norm(df2.loc[i, "proposer_vote_boost"])))

plt.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap),
             ax=ax, label="proposer_vote_boost")

# fig.savefig('tau_block__successful_reorgs_w_pb.png')
